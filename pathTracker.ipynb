# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
import glob
path = "../data"

sed_files = glob.glob(path + "/**/*.sed", recursive = True)

# %%
sed_files
# Out:
# ['../data/vulcano/16062019/volcanello/SPOT16_OBSIDIAN_00001.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_CR1_00009.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_CR1_00008.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_SPONGE_LIKE_00004.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_SPONGE_LIKE_00001.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_SPONGE_LIKE_00003.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_SPONGE_LIKE_00002.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_BLACK_00003.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_BLACK_00002.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_BLACK_00001.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_CR1_00003.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_CR1_00002.sed',
#  '../data/vulcano/16062019/volcanello/spot15/SPOT15_CR1_00001.sed',
# ...

# %%
len(sed_files)
# Out:
# 370

# %%
tt = sed_files[0]

# %%
tt.replace('.sed','only.sed')
# Out:
# '../data/vulcano/16062019/volcanello/SPOT16_OBSIDIAN_00001only.sed'
